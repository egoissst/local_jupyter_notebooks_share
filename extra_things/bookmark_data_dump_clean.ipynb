# %%
import pandas as pd
import time

# %%
def convert_epoch_millis_to_date_string(epoch_millis):
    return time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(int(epoch_millis)/1000))

# %%
# df = pd.read_csv('/Users/yash.dalmia/data_to_share/backup/bookmark_data_NBTG_till_7_Feb_21.csv')
# df = pd.read_csv('/Users/yash.dalmia/data_to_share/backup/bookmark_data_ESG_till_7_Feb_21.csv')
df = pd.read_csv('/Users/yash.dalmia/data_to_share/data_bookmark/bookmark_data_NBTG_till_4_march_21.csv')

# %%
df
# Out:
#               _id       A_ID            C_D     type   A_K       A_N  \
# 0      2602158371  720785609  1614844805119  ARTICLE  NBTG  BookMark
# 1      2602156868  732689727  1614843438501  ARTICLE  NBTG  BookMark
# 2      2602156476  705354830  1614843050687  ARTICLE  NBTG  BookMark
# 3      2602154781  737316441  1614841670829  ARTICLE  NBTG  BookMark
# 4      2602154492  733883432  1614841389855  ARTICLE  NBTG  BookMark
# ...           ...        ...            ...      ...   ...       ...
# 21725  2568269027  695370724  1588244433930  ARTICLE  NBTG  BookMark
# 21726  2567917962    6373595  1588047466192  ARTICLE  NBTG  BookMark
# 21727  2567809147  695370724  1587976105588  ARTICLE  NBTG  BookMark
# 21728  2567806397  695370724  1587974622362  ARTICLE  NBTG  BookMark
# 21729  2567284611   23355175  1587730374986  ARTICLE  NBTG  BookMark
#
#                       A_D_N  \
# 0          Bhagirath Prasad
# 1             Lovely sharma
# 2      Subhash chandra Gond
# ...

# %%
# sum(df['C_D']>1600367400000)

# %%
df_filtered = df[df['C_D']>1612117800000]

# %%
print(df_filtered.shape, df.shape)
# Out:
# (1157, 10) (21730, 10)

# %%
df_filtered['time'] = df_filtered['C_D'].apply(convert_epoch_millis_to_date_string)
# Out:
# /Users/yash.dalmia/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_filtered
# Out:
#              _id       A_ID            C_D     type   A_K       A_N  \
# 0     2602158371  720785609  1614844805119  ARTICLE  NBTG  BookMark
# 1     2602156868  732689727  1614843438501  ARTICLE  NBTG  BookMark
# 2     2602156476  705354830  1614843050687  ARTICLE  NBTG  BookMark
# 3     2602154781  737316441  1614841670829  ARTICLE  NBTG  BookMark
# 4     2602154492  733883432  1614841389855  ARTICLE  NBTG  BookMark
# ...          ...        ...            ...      ...   ...       ...
# 1152  2598727219  737496341  1612140810930  ARTICLE  NBTG  BookMark
# 1153  2598727216  737496341  1612140806634  ARTICLE  NBTG  BookMark
# 1154  2598727193  737496341  1612140807887  ARTICLE  NBTG  BookMark
# 1155  2598723962  736558618  1612136226620  ARTICLE  NBTG  BookMark
# 1156  2598716783   11603690  1612122998345  ARTICLE  NBTG  BookMark
#
#                      A_D_N                                                teu  \
# ...

# %%
df_filtered.to_csv('/Users/yash.dalmia/data_to_share/bookmark_data_NBTG_1_feb_21_till_3_march_21.csv', index=False, encoding='utf-8')
